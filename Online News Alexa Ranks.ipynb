# %% [markdown]
# # US Alexa Ranks of Online News Websites

# %% [markdown]
# ## Instructions

# %% [markdown]
# 1. To update Alexa US rank data and overwrite `ranks.csv`, simply run all cells below.
# 2. To add website(s) to the rank data collection, fill in the values in `add_sites` below and run all cells. Make sure to enter the URL that Alexa uses for ranking.
# 3. To remove website(s) from all datasets and from future data collection, add site IDs to `removes_sites` below and run all cells.

# %%
add_sites = [('The Mercury News','mercurynews.com'),('Chicago Sun-Times','suntimes.com'),('The Denver Post','denverpost.com'),('Chicago Tribune','chicagotribune.com'),('The Dallas Morning News','dallasnews.com'),('Newsday','newsday.com'),('Orange County Register','ocregister.com'),('The Star-Ledger','nj.com'),('Tampa Bay Times','tampabay.com'),('The Plain Dealer','cleveland.com'),('The Philadelphia Inquirer','philly.com'),('Star Tribune','startribune.com'),('The Arizona Republic','azcentral.com'),('Honolulu Star-Advertiser','staradvertiser.com'),('Las Vegas Review-Journal','reviewjournal.com'),('The San Diego Union-Tribune','sandiegouniontribune.com'),('The Christian Science Monitor','csmonitor.com')] # list of site (name, url) tuples of strings

# %%
remove_sites = [] # list of site ids (integers)

# %% [markdown]
# ## Package Imports

# %%
import datetime
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
pd.set_option('display.max_colwidth', 1000, 'display.max_rows', None, 'display.max_columns', None)

# %% [markdown]
# ## Sites

# %%
sites = pd.read_csv('sites.csv')

# %% [markdown]
# Add requested sites.

# %%
for (name, url) in add_sites:
    if url not in sites['url']:
        sites = sites.append({'id':sites.id.max()+1, 'name':name, 'url':url}, ignore_index=True)

# %% [markdown]
# Remove requested sites.

# %%
sites = sites.loc[~sites['id'].isin(remove_sites)]

# %% [markdown]
# View full list of sites.

# %%
sites.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 96 entries, 0 to 95
# Data columns (total 3 columns):
# id      96 non-null int64
# name    96 non-null object
# url     96 non-null object
# dtypes: int64(1), object(2)
# memory usage: 3.0+ KB

# %%
sites
# Out:
#     id                                name                          url
# 0    0                     FiveThirtyEight          fivethirtyeight.com
# 1    1                            Politico                 politico.com
# 2    2                               MSNBC                    msnbc.com
# 3    3                     Washington Post           washingtonpost.com
# 4    4                    Business Insider          businessinsider.com
# 5    5                    Washington Times          washingtontimes.com
# 6    6                   The Daily Stormer            dailystormer.name
# 7    7                                CNBC                     cnbc.com
# 8    8                            The Hill                  thehill.com
# 9    9                       The Intercept             theintercept.com
# 10  10                                 CNN                      cnn.com
# 11  11                   Los Angeles Times                  latimes.com
# 12  12                              SFGate                   sfgate.com
# 13  13                       ThinkProgress            thinkprogress.org
# 14  14                       New York Post                   nypost.com
# 15  15                                Vice                     vice.com
# 16  16                    The Daily Caller              dailycaller.com
# 17  17                            CBS News                  cbsnews.com
# 18  18                           Breitbart                breitbart.com
# 19  19            U.S. News & World Report                   usnews.com
# 20  20                              Reason                   reason.com
# 21  21                            Truthout                truth-out.org
# 22  22                               Axios                    axios.com
# 23  23                            Mediaite                 mediaite.com
# 24  24           The American Conservative  theamericanconservative.com
# 25  25                          ProPublica               propublica.org
# 26  26                            Truthdig                 truthdig.com
# 27  27                                 BBC                      bbc.com
# 28  28                         TYT Network               tytnetwork.com
# 29  29                 Wall Street Journal                      wsj.com
# 30  30                          Daily Mail              dailymail.co.uk
# 31  31                       Drudge Report             drudgereport.com
# 32  32                             Fortune                  fortune.com
# 33  33                     National Review           nationalreview.com
# 34  34  Center for Investigative Reporting               revealnews.org
# 35  35                            NBC News                  nbcnews.com
# 36  36                                 Vox                      vox.com
# 37  37                            BuzzFeed                 buzzfeed.com
# 38  38                     The Independent            independent.co.uk
# 39  39                            Infowars                 infowars.com
# 40  40                   RealClearPolitics        realclearpolitics.com
# 41  41                          The Nation                thenation.com
# 42  42                            ABC News               abcnews.go.com
# 43  43                      The New Yorker                newyorker.com
# 44  44                         Daily Beast            thedailybeast.com
# 45  45                            Alternet                 alternet.org
# 46  46                             AP News                   apnews.com
# 47  47                            Newsweek                 newsweek.com
# 48  48                       Time Magazine                     time.com
# 49  49                      New York Times                  nytimes.com
# 50  50                 Talking Points Memo        talkingpointsmemo.com
# 51  52                   Houston Chronicle                    chron.com
# 52  53                 New York Daily News              nydailynews.com
# 53  54                            RawStory                 rawstory.com
# 54  55                           Bloomberg                bloomberg.com
# 55  56                       Common Dreams             commondreams.org
# 56  57                          PolitiFact               politifact.com
# 57  58                     Shareblue Media                shareblue.com
# 58  59                      Democracy Now!             democracynow.org
# 59  60                        Mother Jones              motherjones.com
# 60  61           Media Matters for America             mediamatters.org
# 61  62                           USA Today                 usatoday.com
# 62  63                               Slate                    slate.com
# 63  64                             Reuters                  reuters.com
# 64  65                                 NPR                      npr.org
# 65  66                          Daily Wire                dailywire.com
# 66  67                           Daily Kos                 dailykos.com
# 67  68                        The Guardian              theguardian.com
# 68  69                            HuffPost           huffingtonpost.com
# 69  70                    The Boston Globe              bostonglobe.com
# 70  71                 Washington Examiner       washingtonexaminer.com
# 71  72                        The Atlantic              theatlantic.com
# 72  73                            Fox News                  foxnews.com
# 73  74        International Business Times                  ibtimes.com
# 74  75                 Conservative Review       conservativereview.com
# 75  76                               Salon                    salon.com
# 76  78                            New York                    nymag.com
# 77  79                            The Week                  theweek.com
# 78  80                           Inquisitr                inquisitr.com
# 79  81                    The Mercury News              mercurynews.com
# 80  82                   Chicago Sun-Times                 suntimes.com
# 81  83                     The Denver Post               denverpost.com
# 82  84                     Chicago Tribune           chicagotribune.com
# 83  85             The Dallas Morning News               dallasnews.com
# 84  86                             Newsday                  newsday.com
# 85  87              Orange County Register               ocregister.com
# 86  88                     The Star-Ledger                       nj.com
# 87  89                     Tampa Bay Times                 tampabay.com
# 88  90                    The Plain Dealer                cleveland.com
# 89  91           The Philadelphia Inquirer                   philly.com
# 90  92                        Star Tribune              startribune.com
# 91  93                The Arizona Republic                azcentral.com
# 92  94            Honolulu Star-Advertiser           staradvertiser.com
# 93  95            Las Vegas Review-Journal            reviewjournal.com
# 94  96         The San Diego Union-Tribune     sandiegouniontribune.com
# 95  97       The Christian Science Monitor                csmonitor.com

# %% [markdown]
# Save `sites`.

# %%
sites.to_csv('sites.csv', index=False)

# %% [markdown]
# ## Ranks

# %%
ranks = pd.read_csv('ranks.csv')

# %% [markdown]
# Remove requested sites.

# %%
ranks = ranks.loc[~ranks['id'].isin(remove_sites)]

# %% [markdown]
# Current ranks info:

# %%
ranks.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1085 entries, 0 to 1084
# Data columns (total 3 columns):
# datetime    1085 non-null object
# id          1085 non-null int64
# rank        1085 non-null int64
# dtypes: int64(2), object(1)
# memory usage: 33.9+ KB

# %%
ranks.sample(3)
# Out:
#                        datetime  id  rank
# 786  2018-03-11 00:23:01.467944  17   205
# 896  2018-03-12 06:23:21.051266  48   190
# 23   2017-11-15 12:00:00.000000  39   844

# %% [markdown]
# ## Scrape Current Site Ranks

# %%
def find_rank(url):
    'Scrape the Alexa Rank in the United States of the given URL'
    try:
        dfs = pd.read_html('http://www.alexa.com/siteinfo/%s' % url)
        idx = 0
        while True:
            country_ranks = dfs[idx]
            try:
                country_ranks.set_index('Country', inplace=True)
                return country_ranks.loc['United States', 'Rank in Country']
            except:
                idx += 1
    except:
        print('\tWARNING: Lookup failed on %s' % url)
        return np.nan

# %% [markdown]
# Find the currents ranks of all sites in `sites` and append the results to `ranks`.

# %%
dtime = datetime.datetime.utcnow() # Current UTC datetime

print('Scraping current site ranks...')
for idx in range(sites.shape[0]):
    siterank = find_rank(sites.loc[idx, 'url'])
    if pd.notnull(siterank):
        ranks = ranks.append({'datetime':dtime, 'id':sites.loc[idx, 'id'], 'rank':siterank}, ignore_index=True)
    
print('Done')
# Out:
# Scraping current site ranks...
# Done

# %%
ranks.tail()
# Out:
#                         datetime  id  rank
# 1176  2018-03-18 03:42:21.067966  93  2072
# 1177  2018-03-18 03:42:21.067966  94  6114
# 1178  2018-03-18 03:42:21.067966  95  4449
# 1179  2018-03-18 03:42:21.067966  96  2449
# 1180  2018-03-18 03:42:21.067966  97  4713

# %% [markdown]
# Save `ranks.csv`.

# %%
ranks.to_csv('ranks.csv', index=False)

# %% [markdown]
# ## Data Merging and Pivoting

# %% [markdown]
# Convert datetime strings to datetime objects.

# %%
ranks.loc[:,'datetime'] = pd.to_datetime(ranks['datetime'])

# %% [markdown]
# Create dataframe with datetime, name, and rank data merged from `sites` and `ranks`.

# %%
site_ranks = ranks.merge(sites, on='id')
site_ranks = site_ranks.loc[:, ['datetime', 'name', 'rank']]

# %%
site_ranks.sample(3)
# Out:
#                       datetime                          name  rank
# 212 2018-03-04 03:34:24.925354                          CNBC   145
# 643 2018-03-15 06:15:46.692040                    PolitiFact  1987
# 230 2018-03-06 23:22:57.580046  International Business Times  4725

# %% [markdown]
# Pivot `site_ranks`.

# %%
site_ranks = site_ranks.pivot(index='datetime', columns='name', values='rank')

# %% [markdown]
# ## Most Recent Ranks

# %% [markdown]
# ### Sorted by Site Name

# %%
pd.DataFrame({'US Alexa Rank, %s' % site_ranks.index[-1].date():site_ranks.iloc[-1]})
# Out:
#                                     US Alexa Rank, 2018-03-18
# name
# ABC News                                                250.0
# AP News                                                1027.0
# Alternet                                               3002.0
# Axios                                                   978.0
# BBC                                                      79.0
# Bloomberg                                               165.0
# Breitbart                                                60.0
# Business Insider                                        108.0
# BuzzFeed                                                 68.0
# CBS News                                                206.0
# CNBC                                                    155.0
# CNN                                                      25.0
# Center for Investigative Reporting                    32889.0
# Chicago Sun-Times                                      2266.0
# Chicago Tribune                                         398.0
# Common Dreams                                          5757.0
# Conservative Review                                   17610.0
# Daily Beast                                             308.0
# Daily Kos                                               873.0
# Daily Mail                                              107.0
# Daily Wire                                              845.0
# Democracy Now!                                         6033.0
# Drudge Report                                           157.0
# FiveThirtyEight                                         347.0
# Fortune                                                 730.0
# Fox News                                                 57.0
# Honolulu Star-Advertiser                               6114.0
# Houston Chronicle                                       342.0
# HuffPost                                                 77.0
# Infowars                                               1009.0
# Inquisitr                                              2188.0
# International Business Times                           4735.0
# Las Vegas Review-Journal                               4449.0
# Los Angeles Times                                       208.0
# MSNBC                                                   598.0
# Media Matters for America                              7459.0
# Mediaite                                               1647.0
# Mother Jones                                           1654.0
# NBC News                                                198.0
# NPR                                                     127.0
# National Review                                        1374.0
# New York                                                652.0
# New York Daily News                                     354.0
# New York Post                                           169.0
# New York Times                                           31.0
# Newsday                                                2424.0
# Newsweek                                                433.0
# Orange County Register                                 2346.0
# PolitiFact                                             2001.0
# Politico                                                228.0
# ProPublica                                             4214.0
# RawStory                                               1010.0
# RealClearPolitics                                      1134.0
# Reason                                                 2764.0
# Reuters                                                 268.0
# SFGate                                                  313.0
# Salon                                                  1167.0
# Shareblue Media                                        7041.0
# Slate                                                   321.0
# Star Tribune                                           1401.0
# TYT Network                                           10228.0
# Talking Points Memo                                    1525.0
# Tampa Bay Times                                        1625.0
# The American Conservative                              9135.0
# The Arizona Republic                                   2072.0
# The Atlantic                                            231.0
# The Boston Globe                                        959.0
# The Christian Science Monitor                          4713.0
# The Daily Caller                                        187.0
# The Daily Stormer                                      7487.0
# The Dallas Morning News                                1664.0
# The Denver Post                                        1630.0
# The Guardian                                            112.0
# The Hill                                                174.0
# The Independent                                         404.0
# The Intercept                                          2200.0
# The Mercury News                                       1073.0
# The Nation                                             3814.0
# The New Yorker                                          408.0
# The Philadelphia Inquirer                              1551.0
# The Plain Dealer                                       1605.0
# The San Diego Union-Tribune                            2449.0
# The Star-Ledger                                         745.0
# The Week                                               1184.0
# ThinkProgress                                          1062.0
# Time Magazine                                           205.0
# Truthdig                                              14811.0
# Truthout                                              11930.0
# U.S. News & World Report                                197.0
# USA Today                                               100.0
# Vice                                                     80.0
# Vox                                                     310.0
# Wall Street Journal                                     150.0
# Washington Examiner                                    1467.0
# Washington Post                                          59.0
# Washington Times                                       1513.0

# %% [markdown]
# ### Sorted by Rank

# %%
site_ranks.sort_values(by=site_ranks.index[-1], axis=1, inplace=True)

# %%
pd.DataFrame({'US Alexa Rank, %s' % site_ranks.index[-1].date():site_ranks.iloc[-1]})
# Out:
#                                     US Alexa Rank, 2018-03-18
# name
# CNN                                                      25.0
# New York Times                                           31.0
# Fox News                                                 57.0
# Washington Post                                          59.0
# Breitbart                                                60.0
# BuzzFeed                                                 68.0
# HuffPost                                                 77.0
# BBC                                                      79.0
# Vice                                                     80.0
# USA Today                                               100.0
# Daily Mail                                              107.0
# Business Insider                                        108.0
# The Guardian                                            112.0
# NPR                                                     127.0
# Wall Street Journal                                     150.0
# CNBC                                                    155.0
# Drudge Report                                           157.0
# Bloomberg                                               165.0
# New York Post                                           169.0
# The Hill                                                174.0
# The Daily Caller                                        187.0
# U.S. News & World Report                                197.0
# NBC News                                                198.0
# Time Magazine                                           205.0
# CBS News                                                206.0
# Los Angeles Times                                       208.0
# Politico                                                228.0
# The Atlantic                                            231.0
# ABC News                                                250.0
# Reuters                                                 268.0
# Daily Beast                                             308.0
# Vox                                                     310.0
# SFGate                                                  313.0
# Slate                                                   321.0
# Houston Chronicle                                       342.0
# FiveThirtyEight                                         347.0
# New York Daily News                                     354.0
# Chicago Tribune                                         398.0
# The Independent                                         404.0
# The New Yorker                                          408.0
# Newsweek                                                433.0
# MSNBC                                                   598.0
# New York                                                652.0
# Fortune                                                 730.0
# The Star-Ledger                                         745.0
# Daily Wire                                              845.0
# Daily Kos                                               873.0
# The Boston Globe                                        959.0
# Axios                                                   978.0
# Infowars                                               1009.0
# RawStory                                               1010.0
# AP News                                                1027.0
# ThinkProgress                                          1062.0
# The Mercury News                                       1073.0
# RealClearPolitics                                      1134.0
# Salon                                                  1167.0
# The Week                                               1184.0
# National Review                                        1374.0
# Star Tribune                                           1401.0
# Washington Examiner                                    1467.0
# Washington Times                                       1513.0
# Talking Points Memo                                    1525.0
# The Philadelphia Inquirer                              1551.0
# The Plain Dealer                                       1605.0
# Tampa Bay Times                                        1625.0
# The Denver Post                                        1630.0
# Mediaite                                               1647.0
# Mother Jones                                           1654.0
# The Dallas Morning News                                1664.0
# PolitiFact                                             2001.0
# The Arizona Republic                                   2072.0
# Inquisitr                                              2188.0
# The Intercept                                          2200.0
# Chicago Sun-Times                                      2266.0
# Orange County Register                                 2346.0
# Newsday                                                2424.0
# The San Diego Union-Tribune                            2449.0
# Reason                                                 2764.0
# Alternet                                               3002.0
# The Nation                                             3814.0
# ProPublica                                             4214.0
# Las Vegas Review-Journal                               4449.0
# The Christian Science Monitor                          4713.0
# International Business Times                           4735.0
# Common Dreams                                          5757.0
# Democracy Now!                                         6033.0
# Honolulu Star-Advertiser                               6114.0
# Shareblue Media                                        7041.0
# Media Matters for America                              7459.0
# The Daily Stormer                                      7487.0
# The American Conservative                              9135.0
# TYT Network                                           10228.0
# Truthout                                              11930.0
# Truthdig                                              14811.0
# Conservative Review                                   17610.0
# Center for Investigative Reporting                    32889.0

# %% [markdown]
# ## Visualizations

# %% [markdown]
# ### Most Recent Site Ranks

# %%
import plotly
import plotly.plotly as py
import plotly.graph_objs as go

# %%
plotly.tools.set_credentials_file(username='jgcorliss', api_key='4vKw6KTPiNvhVdVZTYAv')

# %%
#cf.set_config_file(theme='white')
data = [go.Bar(y=site_ranks.columns, x=site_ranks.iloc[-1], orientation='h')]
layout = go.Layout(
    title='Most Recent Site Ranks - %s UTC' % site_ranks.index[-1],
    yaxis={},
    xaxis={'title':'US Alexa Rank', 'type':'log'},
    showlegend=False,
    height=1600,
    margin={'l':200},
    hovermode='closest',
    hoverlabel={'bgcolor':'white', 'namelength':-1}
)
fig = go.Figure(data=data, layout=layout)
py.iplot(fig, filename='alexa-ranks-current')
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~jgcorliss/12.embed" height="1600px" width="100%"></iframe>

# %% [markdown]
# Link to this plot: https://plot.ly/~jgcorliss/12/

# %% [markdown]
# ### Site Ranks History

# %%
data = [go.Scatter(x=site_ranks.index, y=site_ranks[col], mode="markers+lines", name=col) for col in site_ranks.columns]
layout = go.Layout(
    title='Site Ranks History',
    xaxis={'title':'Datetime (UTC)'},
    yaxis={'title':'US Alexa Rank', 'type':'log'},
    showlegend=False,
    height=2400,
    hovermode='closest',
    hoverlabel={'namelength':-1}
)
fig = go.Figure(data=data, layout=layout)
py.iplot(fig, filename='alexa-ranks-history')
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~jgcorliss/14.embed" height="2400px" width="100%"></iframe>

# %% [markdown]
# Link to this plot: https://plot.ly/~jgcorliss/14/
